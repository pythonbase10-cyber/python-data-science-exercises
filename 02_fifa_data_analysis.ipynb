# %%
import pandas as pd

from aula_1 import dados

df = pd.read_csv('csv/fifa.csv')
df.head() # No Jupyter, você não precisa de print() na última linha da célula
# Out:
# Minha tabela de compras
#   Produto  Preço  Quantidade
# 0   Leite    5.0           2
# 1     Pao    3.5           5
# 2    Café   15.0           1
# 3   Arroz   20.0           2
#
# --- Tabela com o total calculado___
#
# ___Filtros que custam mais de R$ 10,00 reais___
#   Produto  Preço  Quantidade  Total
# 2    Café   15.0           1   15.0
# 3   Arroz   20.0           2   40.0
#
# ___Filtros que custam menos de R$ 10,00 reais___
#   Produto  Preço  Quantidade  Total
# 0   Leite    5.0           2   10.0
# 1     Pao    3.5           5   17.5
# Total gasto economicos R$: 27.50
# Total de itens caros R$: 40.00
#  O item mais caro da lista é:  Arroz
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
# ...

# %%
df[['Name','Age']].head()
# Out:
#                 Name  Age
# 0           L. Messi   31
# 1  Cristiano Ronaldo   33
# 2          Neymar Jr   26
# 3             De Gea   27
# 4       K. De Bruyne   27

# %%
df[['Club','Penalties']].head()
# Out:
#                   Club  Penalties
# 0         FC Barcelona       75.0
# 1             Juventus       85.0
# 2  Paris Saint-Germain       81.0
# 3    Manchester United       40.0
# 4      Manchester City       79.0

# %%
df.head(2) # mostra os primeiros
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona  ...
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus  ...
#
#   Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 0      96.0    33.0           28.0           26.0      6.0        11.0
# 1      95.0    28.0           31.0           23.0      7.0        11.0
#
#    GKKicking  GKPositioning GKReflexes Release Clause
# 0       15.0           14.0        8.0        €226.5M
# 1       15.0           14.0       11.0        €127.1M
#
# ...

# %%
df.tail() # mostra os ultimos
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %%
df.columns # todas as colunas
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.iloc[15] #mostra apenas o selecionado
# Out:
# Unnamed: 0                                                    15
# ID                                                        211110
# Name                                                   P. Dybala
# Age                                                           24
# Photo             https://cdn.sofifa.org/players/4/19/211110.png
#                                        ...
# GKHandling                                                   4.0
# GKKicking                                                    4.0
# GKPositioning                                                5.0
# GKReflexes                                                   8.0
# Release Clause                                           €153.5M
# Name: 15, Length: 89, dtype: object

# %%
df.iloc[6,4]
# Out:
# 'https://cdn.sofifa.org/players/4/19/177003.png'

# %%
df.loc[df['Nationality']== 'Argentina']
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 0               0  158023        L. Messi   31
# 15             15  211110       P. Dybala   24
# 23             23  153079       S. Agüero   30
# 38             38  167664      G. Higuaín   30
# 43             43  201399       M. Icardi   25
# ...           ...     ...             ...  ...
# 17349       17349  240955        T. Durso   19
# 17355       17355  237125      V. Barbero   17
# 17638       17638  236431      E. Alarcón   25
# 17861       17861  245726   F. Bustamante   19
# 17987       17987  241099  L. Finochietto   21
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 15     https://cdn.sofifa.org/players/4/19/211110.png   Argentina
# 23     https://cdn.sofifa.org/players/4/19/153079.png   Argentina
# 38     https://cdn.sofifa.org/players/4/19/167664.png   Argentina
# ...

# %%
df.sort_values(['Name', 'Age', 'Weight']) #mostra essas informacoes
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 13632       13632  228006        A. Abang   21
# 15665       15665  243896   A. Abdellaoui   25
# 3055         3055  198076    A. Abdennour   28
# 6388         6388  138698         A. Abdi   31
# 12816       12816  245438   A. Abdu Jaber   21
# ...           ...     ...             ...  ...
# 15334       15334  246284       Óscar Gil   20
# 9803         9803  229865    Óscar Pinchi   22
# 2564         2564  208621     Óscar Plano   27
# 10353       10353  243558  Óscar Valentín   23
# 10002       10002  220433   Óscar Whalley   24
#
#                                                 Photo  Nationality  \
# 13632  https://cdn.sofifa.org/players/4/19/228006.png     Cameroon
# 15665  https://cdn.sofifa.org/players/4/19/243896.png      Algeria
# 3055   https://cdn.sofifa.org/players/4/19/198076.png      Tunisia
# 6388   https://cdn.sofifa.org/players/4/19/138698.png  Switzerland
# ...

# %%
df['Total'] = df['Acceleration'] + df['Agility'] + df['Reactions']
df  #adiciona uma coluna
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df = df[['Name', 'Nationality', 'Total']]
df.sort_values('Total', ascending=False)
# Out:
#                  Name     Nationality  Total
# 2           Neymar Jr          Brazil  284.0
# 5           E. Hazard         Belgium  279.0
# 0            L. Messi       Argentina  277.0
# 26           M. Salah           Egypt  276.0
# 25          K. Mbappé          France  275.0
# ...               ...             ...    ...
# 13279    P. Mazzocchi           Italy    NaN
# 13280       Y. Ammour          France    NaN
# 13281  Jwa Joon Hyeop  Korea Republic    NaN
# 13282      O. Marrufo          Mexico    NaN
# 13283     Han Pengfei        China PR    NaN
#
# [18207 rows x 3 columns]

# %%
df.to_csv('Teste1.csv', index=False) # aqui ele cria um arquivo novo alterado e exclui a coluna index q foi gerada

# %%
df.to_excel('Teste2.xlsx', index=False)

# %%
df.to_csv('Teste3.txt', index=False, sep='\t')
